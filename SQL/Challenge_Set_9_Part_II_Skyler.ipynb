# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
# cnx = create_engine('postgresql://username:password@ip_address:port')
cnx = create_engine('postgresql://skyler:*********@18.217.201.46:5432')

# %%
# for testing
pd.read_sql_query('''SELECT * FROM allstarfull LIMIT 5''', cnx)
# Out:
#     playerid  yearid gamenum        gameid teamid lgid gp startingpos
# 0  gomezle01    1933       0  ALS193307060    NYA   AL  1           1
# 1  ferreri01    1933       0  ALS193307060    BOS   AL  1           2
# 2  gehrilo01    1933       0  ALS193307060    NYA   AL  1           3
# 3  gehrich01    1933       0  ALS193307060    DET   AL  1           4
# 4  dykesji01    1933       0  ALS193307060    CHA   AL  1           5

# %% [markdown]
# # 1

# %%
pd.read_sql_query('''select yearid, teamid, avg(salary) from salaries group by yearid, teamid;''', cnx)
# Out:
#      yearid teamid           avg
# 0      1999    KCA  7.087838e+05
# 1      2011    FLO  2.190154e+06
# 2      1985    SLN  4.726833e+05
# 3      2010    SEA  3.089643e+06
# 4      2012    MIA  4.373259e+06
# 5      2005    ARI  2.308488e+06
# 6      2002    TBA  1.227857e+06
# 7      2006    TOR  2.744808e+06
# 8      2008    HOU  3.293719e+06
# 9      2001    OAK  1.252250e+06
# 10     1987    TOR  4.556305e+05
# 11     2008    PIT  1.872684e+06
# 12     1988    TOR  4.708163e+05
# 13     2006    CLE  2.241260e+06
# 14     2005    TEX  1.801581e+06
# 15     1998    MIL  9.974972e+05
# 16     1997    CLE  1.832337e+06
# 17     1990    NYA  6.337066e+05
# 18     2011    PIT  1.553345e+06
# 19     2011    KCA  1.373538e+06
# 20     1986    DET  4.568783e+05
# 21     2007    MIL  2.629130e+06
# 22     1998    SEA  1.423343e+06
# 23     1998    NYA  2.087715e+06
# 24     2010    FLO  2.112212e+06
# 25     2008    LAN  4.089260e+06
# 26     2009    DET  4.110184e+06
# ...

# %% [markdown]
# # 2

# %%
pd.read_sql_query('''create table if not exists fielding (
playerID text,
yearID int,
stint int,
teamID text,
lgID text,
POS text,
G int,
GS int,
InnOuts int,
PO int,
A int,
E int,
DP int,
PB int,
WP int,
SB int,
CS int,
ZR int);''', cnx)

# %%
pd.read_sql_query('''COPY fielding FROM '/home/skyler/baseballdata/fielding.csv' DELIMITER ',' CSV HEADER;''', cnx)

# %% [markdown]
# # 3

# %%
pd.read_sql_query('''select playerid, count(playerid) from AllstarFull group by playerid 
order by count(playerid) desc;''', cnx)
# Out:
#        playerid  count
# 0     aaronha01     25
# 1     musiast01     24
# 2      mayswi01     24
# 3     mantlmi01     20
# 4     ripkeca01     19
# 5     willite01     19
# 6     yastrca01     18
# 7     berrayo01     18
# 8     kalinal01     18
# 9     robinbr01     18
# 10    carewro01     18
# 11    spahnwa01     17
# 12     rosepe01     17
# 13    clemero01     15
# 14      foxne01     15
# 15    gwynnto01     15
# 16    smithoz01     15
# 17    jacksre01     14
# 18    rodrial01     14
# 19    benchjo01     14
# 20    bankser01     14
# 21    robinfr02     14
# 22    rodriiv01     14
# 23    bondsba01     14
# 24    jeterde01     13
# 25    dimagjo01     13
# 26    riverma01     13
# 27    griffke02     13
# 28    brettge01     13
# 29    killeha01     13
# ...         ...    ...
# 1646  swishni01      1
# 1647    foxpe01      1
# 1648  thomago01      1
# 1649   garrra01      1
# 1650  leagubr01      1
# 1651  waldejo01      1
# 1652  heywaja01      1
# 1653  jonescl01      1
# ...

# %% [markdown]
# # 4

# %%
pd.read_sql_query('''create table if not exists SchoolsPlayers (
playerID text,
schoolID text,
yearMin int,
yearMax int);''', cnx)

# %%
pd.read_sql_query('''COPY SchoolsPlayers FROM '/home/skyler/baseballdata/SchoolsPlayers.csv' 
DELIMITER ',' CSV HEADER;''', cnx)

# %%
pd.read_sql_query('''SELECT COUNT(playerID), schoolID FROM SchoolsPlayers GROUP BY schoolID ORDER BY count(playerID) 
DESC LIMIT 1;''', cnx)
# Out:
#    count schoolid
# 0    102      usc

# %% [markdown]
# # 5

# %%
pd.read_sql_query('''create table Master (
playerID text,
birthYear int,
birthMonth int,
birthDay int,
birthCountry text,
birthState text,
birthCity text,
deathYear int,
deathMonth int,
deathDay int,
deathCountry text,
deathState text,
deathCity text,
nameFirst text,
nameLast text,
nameGiven text,
weight int,
height int,
bats text,
throws text,
debut text,
finalGame text,
retroID text,
bbrefID text);''', cnx)

# %%
pd.read_sql_query('''COPY Master FROM '/home/skyler/baseballdata/Master.csv' DELIMITER ',' CSV HEADER;''', cnx)

# %%
pd.read_sql_query('''SELECT playerID, DATE(finalGame)-DATE(debut) AS DiffDate FROM Master WHERE finalGame IS NOT NULL 
ORDER BY DiffDate DESC LIMIT 1;''', cnx)
# Out:
#     playerid  diffdate
# 0  altroni01     12862

# %% [markdown]
# # 6

# %%
pd.read_sql_query('''SELECT EXTRACT(MONTH FROM DATE(debut)) AS Month, COUNT(debut) 
FROM Master WHERE debut IS NOT NULL GROUP BY Month ORDER BY Month;''', cnx)
# Out:
#    month  count
# 0    3.0     41
# 1    4.0   4711
# 2    5.0   2230
# 3    6.0   1893
# 4    7.0   1978
# 5    8.0   1943
# 6    9.0   5061
# 7   10.0    308

# %% [markdown]
# # 7

# %%
pd.read_sql_query('''SELECT * FROM Salaries LEFT JOIN Master ON Salaries.playerID=Master.playerID;''', cnx)
# Out:
#        yearid teamid lgid   playerid      salary   playerid  birthyear  \
# 0        1985    BAL   AL  murraed02   1472819.0  murraed02       1956
# 1        1985    BAL   AL   lynnfr01   1090000.0   lynnfr01       1952
# 2        1985    BAL   AL  ripkeca01    800000.0  ripkeca01       1960
# 3        1985    BAL   AL   lacyle01    725000.0   lacyle01       1948
# 4        1985    BAL   AL  flanami01    641667.0  flanami01       1951
# 5        1985    BAL   AL  boddimi01    625000.0  boddimi01       1957
# 6        1985    BAL   AL  stewasa01    581250.0  stewasa01       1954
# 7        1985    BAL   AL  martide01    560000.0  martide01       1954
# 8        1985    BAL   AL  roeniga01    558333.0  roeniga01       1954
# 9        1985    BAL   AL  mcgresc01    547143.0  mcgresc01       1954
# 10       1985    BAL   AL  dempsri01    512500.0  dempsri01       1949
# 11       1985    BAL   AL  grosswa01    483333.0  grosswa01       1952
# ...

# %%
pd.read_sql_query('''SELECT * FROM Master LEFT JOIN Salaries ON Master.playerID=Salaries.playerID;''', cnx)
# Out:
#         playerid  birthyear  birthmonth  birthday birthcountry  \
# 0      murraed02     1956.0         2.0      24.0          USA
# 1       lynnfr01     1952.0         2.0       3.0          USA
# 2      ripkeca01     1960.0         8.0      24.0          USA
# 3       lacyle01     1948.0         4.0      10.0          USA
# 4      flanami01     1951.0        12.0      16.0          USA
# 5      boddimi01     1957.0         8.0      23.0          USA
# 6      stewasa01     1954.0        10.0      28.0          USA
# 7      martide01     1954.0         5.0      14.0    Nicaragua
# 8      roeniga01     1954.0        12.0       5.0          USA
# 9      mcgresc01     1954.0         1.0      18.0          USA
# 10     dempsri01     1949.0         9.0      13.0          USA
# 11     grosswa01     1952.0         1.0      14.0          USA
# 12     dauerri01     1952.0         7.0      27.0          USA
# 13      fordda01     1952.0         5.0      19.0          USA
# ...
